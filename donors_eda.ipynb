# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
data = pd.read_csv('census.csv')

# %%
data.head()
# Out:
#    age          workclass education_level  education-num       marital-status  \
# 0   39          State-gov       Bachelors             13        Never-married
# 1   50   Self-emp-not-inc       Bachelors             13   Married-civ-spouse
# 2   38            Private         HS-grad              9             Divorced
# 3   53            Private            11th              7   Married-civ-spouse
# 4   28            Private       Bachelors             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country income
# ...

# %%
data.shape
# Out:
# (45222, 14)

# %%
data['income_b'] = [0 if  i == '<=50K' else 1 for i in data.income]

# %%
data.head()
# Out:
#    age          workclass education_level  education-num       marital-status  \
# 0   39          State-gov       Bachelors             13        Never-married
# 1   50   Self-emp-not-inc       Bachelors             13   Married-civ-spouse
# 2   38            Private         HS-grad              9             Divorced
# 3   53            Private            11th              7   Married-civ-spouse
# 4   28            Private       Bachelors             13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male          2174
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country income  income_b
# ...

# %%
#plt.figure(figsize = (20,10))
#i = 1
#for c in data.columns:
#    if c in ['income', 'income_b']:
#        continue
    
#    plt.subplot(1,13,i)
#    plt.scatter(data[c], data.income_b)
#    i+=1

# %%
sns.pairplot(data, x_vars = ['age', 'workclass','education_level'], y_vars = ['income_b'],
            height = 4, aspect =2);

# %%
sns.PairGrid(data, x_vars = ['age', 'education_level', 'sex', 'capital-gain'], y_vars = ['income_b']);

# %%
sns.pairplot(data, hue = 'income_b')

# %%
sns.stripplot(data = data, hue = 'income_b')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-911473f4a1d8> in <module>
# ----> 1 sns.stripplot(data = data, hue = 'income_b')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2793
#    2794     plotter = _StripPlotter(x, y, hue, data, order, hue_order,
# -> 2795                             jitter, dodge, orient, color, palette)
#    2796     if ax is None:
#    2797         ax = plt.gca()
#
# ...

# %%
from dython.nominal import associations

# %%
M = associations(data,figsize = (15,10))

# %%
income_corr = M['corr'].loc['income']
values = income_corr[np.argsort(income_corr)[::-1]]
values

# %%
data.relationship.unique()

# %% [markdown]
# |     Metric     | Unoptimized Model | Optimized Model |
# | :------------: | :---------------: | :-------------: |
# | Accuracy Score |        84.2%      |   85.6%         |
# | F-score        |        .72        |   .68           |
